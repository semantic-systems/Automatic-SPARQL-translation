# %% [markdown]
# # SPARQL Test for Wikidata and DBpedia with LC-QuAD 2.0

# %%
# import all the necessary libraries
import requests
import json
import matplotlib.pyplot as plt
import pandas as pd
import re
from SPARQLWrapper import SPARQLWrapper, JSON

# %% [markdown]
# ## Get distinct template_ids
# Extracting all distinct template_ids from the LC-QuAD 2.0 dataset. This is done to see if all template_ids are covered by the number of test queries/questions. Here it should also be seen if certain queries templates are not working at all, meaning there is not problem with updated information or something, but that the template type is not supported, by either of the endpoints (https://skynet.coypu.org/wikidata/; localhost:8890/sparql).

# %%
# Load the LC-QuAD 2.0 dataset
url = "https://raw.githubusercontent.com/AskNowQA/LC-QuAD2.0/refs/heads/master/dataset/train.json"
response = requests.get(url)
lc_quad_data = response.json()

# Extract distinct template_id values from the full dataset
all_template_ids = {entry.get("template_id") for entry in lc_quad_data if "template_id" in entry}

# Extract distinct template_id values from the first 200 questions
first_200_template_ids = {entry.get("template_id") for entry in lc_quad_data[:200] if "template_id" in entry}

# Check if all distinct template_ids from the full dataset are included in the first 200 questions
missing_template_ids = all_template_ids - first_200_template_ids

# Output the results
print("All template_ids from the full dataset:", all_template_ids)
print("Template_ids in the first 200 questions:", first_200_template_ids)

if not missing_template_ids:
    print("All distinct template_ids are included in the first 200 questions.")
else:
    print(f"The following template_ids are missing in the first 200 questions: {missing_template_ids}")
# Out:
# All template_ids from the full dataset: {1, 2, 3, 'statement_property_2', 5, 'Count_1', '1.2', 4, 'Rank1', 'Rank2', 'Count_2', 'statement_property_1', '1.1', '1'}
# Template_ids in the first 200 questions: {1, 2, 3, 'statement_property_2', 5, 'Count_1', '1.2', 4, 'Rank1', 'Rank2', 'Count_2', 'statement_property_1', '1.1', '1'}
# All distinct template_ids are included in the first 200 questions.

# %% [markdown]
# As a result all distinct template_ids are included in the first 200 queries of the LC-QuAD 2.0 dataset.

# %% [markdown]
# ## Querying Wikidata endpoint
# Using the LC-QuAD 2.0 dataset to query the wikidata endpoint (https://skynet.coypu.org/wikidata/). This is done to see if the queries are working and if the endpoint is able to return results. The results should provide answers, those that return "No answer", and queries that fail for some reason (are not properly able to be executed by the endpoint).
#
# In order to achive this the SPARQL queries are executed, sending them to the endpoint and then checking the results and visualizing them in a chart. Further the results are saved in a excel file to manually check the "no answer" queries and see if they also fail when executing them in the skynet web interface as well as in the wiki data query service (https://query.wikidata.org/), also in order to find patterns, e.g. certain template_ids always failing.

# %%
# Define the Skynet Coypu SPARQL endpoint
WIKIDATA_ENDPOINT = "https://skynet.coypu.org/wikidata/"

# Add prefixes once, to avoid repeating this step in each query, this is necessary for the skynet endpoint to work properly
PREFIXES = """
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>
PREFIX pq: <http://www.wikidata.org/prop/qualifier/>
"""

def add_prefixes(sparql_query):
    """Add required prefixes to the SPARQL query."""
    return PREFIXES + sparql_query

# querying the SPARQL endpoint using the SPARQLWrapper library, seting the query and returning in JSON
def query_sparql(endpoint, query):
    """Send a SPARQL query to the specified endpoint and return the results."""
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    sparql.setMethod('GET')
    sparql.setTimeout(60) # Set timeout to 60 seconds to avoid long waits
    try:
        return sparql.query().convert()  # Return results for further processing
    except Exception as e:
        print(f"Query failed: {e}")
        return None  # Query failed

# handle different types of answers from the SPARQL query results. Furhter check if the answer is a Wikidata link or a literal
def extract_answer(results):
    """Extract the answer from the SPARQL query results, handling boolean answers."""
    if not results:
        return ["No answer"]
    
    if 'boolean' in results:
        return ["True"] if results['boolean'] else ["False"]

    answers = []
    bindings = results.get('results', {}).get('bindings', [])
    if not bindings:
        return ["No answer"]

    for binding in bindings:
        for var_name in binding:
            value = binding[var_name]['value']
            if value.startswith("http://www.wikidata.org/entity/"):
                answers.append(value)  # Keep the full Wikidata link
            else:
                answers.append(value)  # Append literals directly
    return answers if answers else ["No answer"]

# Initialize counters for proper/correct answers, no answers, and failures
proper_answer_count = 0
no_answer_count = 0
failure_count = 0

# Lists to hold query results
results = []

# Test the first 200 queries
for entry in lc_quad_data[:200]:
    sparql_query = entry.get('sparql_wikidata')
    question = entry.get('question')
    
    if sparql_query:
        # Add the necessary prefixes to the query
        query_with_prefixes = add_prefixes(sparql_query)
        result = query_sparql(WIKIDATA_ENDPOINT, query_with_prefixes)
        
        if result:
            answer = extract_answer(result)
            if "No answer" in answer:
                no_answer_count += 1
            else:
                proper_answer_count += 1
            results.append((question, 'Success', answer))
        else:
            failure_count += 1
            results.append((question, 'Failure', ['No answer']))

# Print the number of proper answers, no answers, and failures
print(f"Number of queries with proper answers: {proper_answer_count}")
print(f"Number of queries with no answers: {no_answer_count}")
print(f"Number of failed queries: {failure_count}")

# Prepare data for exporting to Excel
df = pd.DataFrame(results, columns=['Question', 'Result', 'Answer'])

# Save results to an Excel file for further inspection
df.to_excel("wikidata_results.xlsx", index=False)

# Visualize the results with a bar chart
labels = ['Proper Answer', 'No Answer', 'Failures']
sizes = [proper_answer_count, no_answer_count, failure_count]

plt.bar(labels, sizes, color=['blue', 'orange', 'red'])
for i in range(len(labels)):
    plt.text(i, sizes[i] + 0.5, str(sizes[i]), ha='center')

plt.title('Count of Queries: Proper Answers vs No Answers vs Failures')
plt.ylabel('Number of Queries')
plt.xlabel('Answer Type')
plt.show()

# Optionally print the results for inspection
for question, result, answer in results:
    print(f"{question}: {result}, Answer: {answer}")
# Out:
# Query failed: The read operation timed out
# Query failed: The read operation timed out
# Number of queries with proper answers: 125
# Number of queries with no answers: 73
# Number of failed queries: 2
# What periodical literature does Delta Air Lines use as a moutpiece?: Success, Answer: ['http://www.wikidata.org/entity/Q3486420']
# Who is the child of Ranavalona I's husband?: Success, Answer: ['http://www.wikidata.org/entity/Q218622']
# Is it true Jeff_Bridges occupation Lane Chandler and photographer ?: Success, Answer: ['False']
# What is the pre-requisite of phase matter of Galinstan?: Success, Answer: ['No answer']
# Which is the operating income for Qantas?: Success, Answer: ['1370000000']
# which cola starts with the letter p: Success, Answer: ['http://www.wikidata.org/entity/Q100147873', 'Pepsi Perfect', 'http://www.wikidata.org/entity/Q47719', 'Pepsi', 'http://www.wikidata.org/entity/Q18387614', 'Pepsi True', 'http://www.wikidata.org/entity/Q3504021', 'Parsi Cola']
# Is the right ascension of malin 1 less than 15.1398?: Success, Answer: ['False']
# What is the complete list of records released by Jerry Lee Lewis?: Success, Answer: ['http://www.wikidata.org/entity/Q3029950']
# What's Mary Lou Retton's International Olympic Committee athlete ID.: Success, Answer: ['mary-lou-retton']
# Who won the prize at the sequel of the 1885 Wimbledon Championships- Gentlemen's Singles?: Success, Answer: ['http://www.wikidata.org/entity/Q365139']
# Is it true that the carbon footprint of the iPhone X Max is 106?: Success, Answer: ['True']
# Tell me the female beauty pageant that operates in all countries and contains the word model in it's name?: Success, Answer: ['http://www.wikidata.org/entity/Q129691', 'Top Model of the World', 'http://www.wikidata.org/entity/Q2004997', 'International Model of the Year', 'http://www.wikidata.org/entity/Q12038095', 'Miss Model of the Year', 'http://www.wikidata.org/entity/Q128144', 'Miss Model of the World', 'http://www.wikidata.org/entity/Q786345', 'Ford Models Supermodel of the World']
# Did Lindsey Vonn participate in the FIS Alpine World Ski Championships in 1999 and 2019?: Success, Answer: ['False']
# When position did Angela Merkel hold on November 10, 1994?: Success, Answer: ['No answer']
# On 0-0-2007, what is the populaton of Spokane?: Success, Answer: ['No answer']
# What essential medicine is needed to treat leprosy?: Success, Answer: ['http://www.wikidata.org/entity/Q422226', 'http://www.wikidata.org/entity/Q418611']
# Which is HanCinema person ID for Zhang Ziyi?: Success, Answer: ['Zhang_Ziyi']
# Did Judi Densch receive a Tony Award for best direction of the play Premium Imperiale?: Success, Answer: ['False']
# What is the boiling point of pressure copper as 4703.0?: Success, Answer: ['No answer']
# After what is Marathon named and what is the current record?: Success, Answer: ['http://www.wikidata.org/entity/Q63223', 'http://www.wikidata.org/entity/Q31900', 'http://www.wikidata.org/entity/Q9124', 'http://www.wikidata.org/entity/Q31900']
# Who Sleepwalking succeeded in playing Sleepwalking?: Success, Answer: ['http://www.wikidata.org/entity/Q494784']
# What did Clifton Chenier get nominated for in 1983-0-0?: Success, Answer: ['No answer']
# Which is the wear for Ambrose Burnside?: Success, Answer: ['No answer']
# Which Class IB flammable liquid has the least lower flammable limit?: Success, Answer: ['http://www.wikidata.org/entity/Q412245', 'http://www.wikidata.org/entity/Q161480', 'http://www.wikidata.org/entity/Q14982', 'http://www.wikidata.org/entity/Q24716723', 'http://www.wikidata.org/entity/Q161282']
# What is the material used and approved by Mojito?: Success, Answer: ['http://www.wikidata.org/entity/Q13195', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q11002', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q488463', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q264554', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q5361217', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q2534652', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q26869768', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q27640062', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q26876993', 'http://www.wikidata.org/entity/Q1430305', 'http://www.wikidata.org/entity/Q26879639', 'http://www.wikidata.org/entity/Q1430305']
# Could you summarize Korea's history of this topic?: Success, Answer: ['http://www.wikidata.org/entity/Q713414']
# "Which is {landscape of} of {Virgin of the rocks}, which has {birth city} is {Tzippori} ?": Success, Answer: ['http://www.wikidata.org/entity/Q345']
# Is Kevin Costner owner of Fielders Stadium?: Success, Answer: ['True']
# Which is the YouTube channel ID for Miley Cyrus?: Success, Answer: ['UCn7dB9UMTBDjKtEKBy_XISw']
# What is a skill that starts with the letter s.: Success, Answer: ['http://www.wikidata.org/entity/Q351363', 'seamanship', 'http://www.wikidata.org/entity/Q331835', 'suction']
# How many dimensions have a Captain America?: Success, Answer: ['1']
# What award did Danila Kozlovsky receive in 2017?: Success, Answer: ['No answer']
# Who is the student that coined the Euler-Lagrange equation?: Success, Answer: ['http://www.wikidata.org/entity/Q80222', 'http://www.wikidata.org/entity/Q4400039', 'http://www.wikidata.org/entity/Q556346', 'http://www.wikidata.org/entity/Q115664', 'http://www.wikidata.org/entity/Q447071', 'http://www.wikidata.org/entity/Q4201322', 'http://www.wikidata.org/entity/Q4235955', 'http://www.wikidata.org/entity/Q4141818']
# Which website does Twitch own?: Success, Answer: ['No answer']
# Is the minimal lethal dose of the benzene equal to 170000?: Success, Answer: ['True']
# Who is the person that was a student of Ivan Pavlov?: Success, Answer: ['http://www.wikidata.org/entity/Q1277949']
# is the clock speed of the Watara Supervision smaller than 3.2?: Success, Answer: ['False']
# What country is the current leader of the African Union ?: Success, Answer: ['http://www.wikidata.org/entity/Q155']
# Who works for the accused Mariposa Folk Festival 1974?: Success, Answer: ['http://www.wikidata.org/entity/Q1530721', 'http://www.wikidata.org/entity/Q1032269', 'http://www.wikidata.org/entity/Q1632007']
# n/a: Success, Answer: ['http://www.wikidata.org/entity/Q290356']
# What sister city was born in of Zakhar Oskotsky?: Success, Answer: ['http://www.wikidata.org/entity/Q31487', 'http://www.wikidata.org/entity/Q270', 'http://www.wikidata.org/entity/Q1085', 'http://www.wikidata.org/entity/Q1792', 'http://www.wikidata.org/entity/Q87', 'http://www.wikidata.org/entity/Q406', 'http://www.wikidata.org/entity/Q641', 'http://www.wikidata.org/entity/Q25319', 'http://www.wikidata.org/entity/Q2145', 'http://www.wikidata.org/entity/Q456', 'http://www.wikidata.org/entity/Q216', 'http://www.wikidata.org/entity/Q90', 'http://www.wikidata.org/entity/Q1861', 'http://www.wikidata.org/entity/Q1757', 'http://www.wikidata.org/entity/Q8686', 'http://www.wikidata.org/entity/Q42810', 'http://www.wikidata.org/entity/Q1449', 'http://www.wikidata.org/entity/Q36036', 'http://www.wikidata.org/entity/Q1055', 'http://www.wikidata.org/entity/Q13298', 'http://www.wikidata.org/entity/Q490', 'http://www.wikidata.org/entity/Q12892', 'http://www.wikidata.org/entity/Q1731', 'http://www.wikidata.org/entity/Q23436', 'http://www.wikidata.org/entity/Q1492', 'http://www.wikidata.org/entity/Q1435', 'http://www.wikidata.org/entity/Q79880', 'http://www.wikidata.org/entity/Q1781', 'http://www.wikidata.org/entity/Q956', 'http://www.wikidata.org/entity/Q52502', 'http://www.wikidata.org/entity/Q1563', 'http://www.wikidata.org/entity/Q17151', 'http://www.wikidata.org/entity/Q2280', 'http://www.wikidata.org/entity/Q9365', 'http://www.wikidata.org/entity/Q1953', 'http://www.wikidata.org/entity/Q18125', 'http://www.wikidata.org/entity/Q9361', 'http://www.wikidata.org/entity/Q1963', 'http://www.wikidata.org/entity/Q585', 'http://www.wikidata.org/entity/Q65', 'http://www
# Tell me organization whose name has the word  zollkriminalamt  in it.: Failure, Answer: ['No answer']
# Which member state of the International Centre for Settlement of Investment Disputes has the maximum inflation rate?: Success, Answer: ['No answer']
# Was Brittany Murphy a citizen of the USA?: Success, Answer: ['True']
# Who is the partner and the spouse of Hank Azaria?: Success, Answer: ['http://www.wikidata.org/entity/Q463482', 'http://www.wikidata.org/entity/Q170574', 'http://www.wikidata.org/entity/Q463482', 'http://www.wikidata.org/entity/Q3700028']
# Does St. Peters Junior School maximum age equal to 11?: Success, Answer: ['True']
# Which country has highest individual tax rate?: Success, Answer: ['http://www.wikidata.org/entity/Q55', 'http://www.wikidata.org/entity/Q55', 'http://www.wikidata.org/entity/Q55', 'http://www.wikidata.org/entity/Q55', 'http://www.wikidata.org/entity/Q55']
# When did James Thomas Farrell receive the St. Louis Literary Award?: Success, Answer: ['No answer']
# When was Pablo Picasso's partnership with Fernade Oliver over?: Success, Answer: ['No answer']
# What is the product with the lowest consumption rate per capita whose has part is paraffin wax?: Success, Answer: ['http://www.wikidata.org/entity/Q22656']
# What are the coordinates for the geographic center of Michigan, as determined by the center of gravity of the surface?: Success, Answer: ['No answer']
# Is the life expectancy of Indonesia 55.3528?: Success, Answer: ['False']
# When did Emmerson Mnangagwa begin going to the University of Zambia?: Success, Answer: ['No answer']
# What kind of career does Grigori Kozintsev have in the screenwriting field?: Success, Answer: ['http://www.wikidata.org/entity/Q28389']
# what is hypothetical protein ecia139-4120 habitat of found in species?: Success, Answer: ['http://www.wikidata.org/entity/Q5880']
# What sovereign state replaced the Kingdom of Great Britain?: Success, Answer: ['No answer']
# Of the century breaks of the Colm Gilcreest equal less than 9.6?: Success, Answer: ['False']
# In which country the Golden Horde used to live ?: Success, Answer: ['http://www.wikidata.org/entity/Q79965']
# Located in the Central District, what is the county seat whose twin cities include Feodosiya?: Success, Answer: ['http://www.wikidata.org/entity/Q221447']
# When did Nicaragua count a population of 3.87732e+06 inhabitants?: Success, Answer: ['No answer']
# What does emigration mean?: Success, Answer: ['No answer']
# Which is the meta-organization that is regulated by the football association?: Success, Answer: ['http://www.wikidata.org/entity/Q253414']
# When was the spouse divorced Nero in 9-6-68: Success, Answer: ['No answer']
# n/a: Success, Answer: ['http://www.wikidata.org/entity/Q1845']
# Former champion Francisco Alarcon gave what award to Art Spiegelaman?: Success, Answer: ['No answer']
# Are there more than 0 survivors of the Charkhi Dadri mid-air collision: Success, Answer: ['True']
# When did Secretariat receive the Triple Crown Trophy?: Success, Answer: ['No answer']
# Which borders of borders of Riverside have a start date of 1984-0-0?: Success, Answer: ['No answer']
# Which is the facility of the defensive wall?: Success, Answer: ['http://www.wikidata.org/entity/Q677678']
# What is  in the IHO Hydrographic Dictionary (S-32) Number of lighthouse ?: Success, Answer: ['2822']
# Which is the fictional analog of Hippocampus?: Success, Answer: ['No answer']
# What is a cause of death that begins with the letter "p" and can be found on a CT scan?: Success, Answer: ['http://www.wikidata.org/entity/Q12192', 'pneumonia']
# What is established by Archbishop of Canterbury, who is a male?: Success, Answer: ['No answer']
# In what area is Fernandel buried at the Passy Cemetery?: Success, Answer: ['No answer']
# Name the naval artillery wirh the smallest firing range?: Success, Answer: ['http://www.wikidata.org/entity/Q45597']
# What is the name of a Cayenne Pepper that also has dates?: Success, Answer: ['No answer']
# Is the throughput of the Vest-vassdraget equal to 2697.672?: Success, Answer: ['False']
# What method did the census use to determine the population of Taguig?: Success, Answer: ['No answer']
# What award did Olga Tokarczuk receive in 2015?: Success, Answer: ['No answer']
# What is Porky Pig in right now?: Success, Answer: ['http://www.wikidata.org/entity/Q622435']
# When did publisher of Pac-Man and place of publication?: Success, Answer: ['No answer']
# Was Aleister Crowley educated at Trinity College and Eton College?: Success, Answer: ['False']
# What is {located next to Quincy,} in the {novel, Infinite Jest}?: Success, Answer: ['http://www.wikidata.org/entity/Q100']
# Who awarded Eric Hobsbawm an honorary doctorate?: Success, Answer: ['No answer']
# What was the last team Allan Border belonged to in the year 1980?: Success, Answer: ['No answer']
# Give me a film character from a fictional universe, such as Marvel comics that starts with a W.: Success, Answer: ['http://www.wikidata.org/entity/Q920406', 'Warpath', 'http://www.wikidata.org/entity/Q996154', 'Wolfsbane', 'http://www.wikidata.org/entity/Q186422', 'Wolverine', 'http://www.wikidata.org/entity/Q770064', 'Warren Worthington III', 'http://www.wikidata.org/entity/Q1403772', 'Weasel', 'http://www.wikidata.org/entity/Q2551564', 'William Stryker']
# Mention the fictional universe described or included in The Matrix.: Success, Answer: ['http://www.wikidata.org/entity/Q20019907']
# What is {award received} of {Hans Krebs} where {point in time} is {1966-0-0} ?: Success, Answer: ['No answer']
# Which record label signed Janet Jackson?: Success, Answer: ['http://www.wikidata.org/entity/Q165745', 'http://www.wikidata.org/entity/Q190585', 'http://www.wikidata.org/entity/Q277626', 'http://www.wikidata.org/entity/Q203059']
# What is Tanzania's total reserves?: Success, Answer: ['No answer']
# Does the slope rating of the Merion Golf Club equal 149: Success, Answer: ['True']
# What is the density of hydrogen peroxide at a temperature of 20.0?: Success, Answer: ['No answer']
# who architecture firm of home field of new york centaurs?: Success, Answer: ['http://www.wikidata.org/entity/Q1111386']
# Which { meansseason starts} in {February} ?: Success, Answer: ['http://www.wikidata.org/entity/Q206984', 'http://www.wikidata.org/entity/Q1351694', 'http://www.wikidata.org/entity/Q22677272', 'http://www.wikidata.org/entity/Q505782', 'http://www.wikidata.org/entity/Q3000144', 'http://www.wikidata.org/entity/Q2707177', 'http://www.wikidata.org/entity/Q57775410', 'http://www.wikidata.org/entity/Q2289847', 'http://www.wikidata.org/entity/Q630141', 'http://www.wikidata.org/entity/Q2686290', 'http://www.wikidata.org/entity/Q83335', 'http://www.wikidata.org/entity/Q1024060', 'http://www.wikidata.org/entity/Q3000405', 'http://www.wikidata.org/entity/Q1033349', 'http://www.wikidata.org/entity/Q635198', 'http://www.wikidata.org/entity/Q1415208', 'http://www.wikidata.org/entity/Q1578389', 'http://www.wikidata.org/entity/Q1103825', 'http://www.wikidata.org/entity/Q2120129', 'http://www.wikidata.org/entity/Q3040
Q217298', 'http://www.wikidata.org/entity/Q294912', 'http://www.wikidata.org/entity/Q483325', 'http://www.wikidata.org/entity/Q718078', 'http://www.wikidata.org/entity/Q43874', 'http://www.wikidata.org/entity/Q29250', 'http://www.wikidata.org/entity/Q186485', 'http://www.wikidata.org/entity/Q315808', 'http://www.wikidata.org/entity/Q521221', 'http://www.wikidata.org/entity/Q287793']
# What is the ammunition of the weapon, that has been used in the war in Southeast Asia?: Success, Answer: ['http://www.wikidata.org/entity/Q259210']
# Tell me every horse breed whose name starts with the letter z: Success, Answer: ['http://www.wikidata.org/entity/Q146898', 'Zangersheide', 'http://www.wikidata.org/entity/Q232350', 'Zweibrücker', 'http://www.wikidata.org/entity/Q20492957', 'Zabaikal', 'http://www.wikidata.org/entity/Q3062589', 'Zaniskari', 'http://www.wikidata.org/entity/Q58307781', 'Zhongdian']
# The University of Florida is a member of which coalition?: Success, Answer: ['http://www.wikidata.org/entity/Q647039']
# Who is the brother in law of the writer Quran?: Success, Answer: ['No answer']
# What is the New Zealand Gazetteer place id for Auckland?: Success, Answer: ['15829']
# What does the painting Grade Odalisque represent which has DRTL backwards?: Success, Answer: ['http://www.wikidata.org/entity/Q133279']
# Name an empire that contains the word "british" in its name: Success, Answer: ['http://www.wikidata.org/entity/Q8680', 'British Empire']
# What is the instance of Antonio da Correggio whose date of birth is 1489-8-1?: Success, Answer: ['No answer']
# Who was the teacher that supervised Shigeno Yasutsugu?: Success, Answer: ['http://www.wikidata.org/entity/Q799829', 'http://www.wikidata.org/entity/Q11356402', 'http://www.wikidata.org/entity/Q11354953', 'http://www.wikidata.org/entity/Q11262380', 'http://www.wikidata.org/entity/Q11531384', 'http://www.wikidata.org/entity/Q11362524', 'http://www.wikidata.org/entity/Q7398823', 'http://www.wikidata.org/entity/Q11373723', 'http://www.wikidata.org/entity/Q11436164', 'http://www.wikidata.org/entity/Q11476354', 'http://www.wikidata.org/entity/Q11495543', 'http://www.wikidata.org/entity/Q11591028', 'http://www.wikidata.org/entity/Q11618283', 'http://www.wikidata.org/entity/Q704098', 'http://www.wikidata.org/entity/Q11660002', 'http://www.wikidata.org/entity/Q11678634', 'http://www.wikidata.org/entity/Q1673895', 'http://www.wikidata.org/entity/Q171418', 'http://www.wikidata.org/entity/Q6280483', 'http://www.wikidata.org/entity/Q6536303', 'http://www.wikidata.org/entity/Q724526', 'http://www.wikidata.org/entity/Q11513131', 'http://www.wikidata.org/entity/Q6533159']
# What is the SANDRE ID for Rhine?: Success, Answer: ['A---0000']
# When did Kylie Minogue receive the Gold Logie Award for Most Popular Personality on Australian Television?: Success, Answer: ['No answer']
# What business does Alexander McQueen have?: Success, Answer: ['http://www.wikidata.org/entity/Q178516', 'http://www.wikidata.org/entity/Q13882231', 'http://www.wikidata.org/entity/Q759210', 'http://www.wikidata.org/entity/Q5559841']
# Tell me the Greek deity of sibling of Zeus and that contains the word poseidon in it's name?: Success, Answer: ['http://www.wikidata.org/entity/Q41127', 'Poseidon']
# Who organizes the order of Ultima III: Exodus?: Success, Answer: ['http://www.wikidata.org/entity/Q250', 'http://www.wikidata.org/entity/Q273140']
# Who was the lead actor for the movie Deadpool?: Success, Answer: ['http://www.wikidata.org/entity/Q192682', 'http://www.wikidata.org/entity/Q1582689', 'http://www.wikidata.org/entity/Q1147104', 'http://www.wikidata.org/entity/Q952156', 'http://www.wikidata.org/entity/Q2056174', 'http://www.wikidata.org/entity/Q28310']
# Mention the musical related work highlighting the work of Sasha Grey.: Success, Answer: ['No answer']
# What award did John de Mol receive in 2011?: Success, Answer: ['No answer']
# Is the total fertility rate of Algeria greater than 3.4284?: Success, Answer: ['False']
# When will the pressure and temperature of water reach the triple point stage?: Success, Answer: ['No answer']
# Tell me physical phenomenon whose name has the word surface in it.: Success, Answer: ['http://www.wikidata.org/entity/Q170749', 'surface tension']
# where does Vladimir putin reside?: Success, Answer: ['No answer']
# Which is the municipality of Belgium that has the headquarters location of European Union?: Success, Answer: ['http://www.wikidata.org/entity/Q239']
# Which is made from the goat meat having a common name as Domestic Goat?: Success, Answer: ['http://www.wikidata.org/entity/Q2934']
# What is located on terrain feature of Multonmah Falls?: Success, Answer: ['http://www.wikidata.org/entity/Q1112581']
# Stonewall Jackson commanded what battle?: Success, Answer: ['http://www.wikidata.org/entity/Q1153610']
# Mention the temperature and the state of the matter of water upon achieving the critical point: Success, Answer: ['No answer']
# which is the point time for syria has population as 8.08815e+06?: Success, Answer: ['No answer']
# Does marketing involve Human communication, and packaging and labeling?: Success, Answer: ['False']
# WHICH IS THE STAGE RACE WITH THE MAXIMUM FREQUENCY OF EVENT: Success, Answer: ['http://www.wikidata.org/entity/Q1015163', 'http://www.wikidata.org/entity/Q1025457', 'http://www.wikidata.org/entity/Q104190274', 'http://www.wikidata.org/entity/Q104637798', 'http://www.wikidata.org/entity/Q105367666']
# WHICH IS THE AUSTRIAN MUNICIPALITY KEY OF  KLAGENFURT: Success, Answer: ['20101']
# Tell me the autonomous region of the People's Republic of China which contains the word xinjiang in it's name?: Success, Answer: ['http://www.wikidata.org/entity/Q34800', 'Xinjiang']
# What is the Velká pardubická with the lowest race time whose winner is Peter Gehm?: Success, Answer: ['http://www.wikidata.org/entity/Q11878824', 'http://www.wikidata.org/entity/Q11878821', 'http://www.wikidata.org/entity/Q11878818', 'http://www.wikidata.org/entity/Q11878819']
# Who is the author of the Watchmen and what award did they receive?: Success, Answer: ['http://www.wikidata.org/entity/Q20899118', 'http://www.wikidata.org/entity/Q205739', 'http://www.wikidata.org/entity/Q20899118', 'http://www.wikidata.org/entity/Q445765']
# n/a: Success, Answer: ['http://www.wikidata.org/entity/Q2394955', 'http://www.wikidata.org/entity/Q1772298', 'http://www.wikidata.org/entity/Q3471500', 'http://www.wikidata.org/entity/Q28935701']
# Name a book written in Esperanto: Success, Answer: ['http://www.wikidata.org/entity/Q105422229', 'http://www.wikidata.org/entity/Q12345685', 'http://www.wikidata.org/entity/Q12351128', 'http://www.wikidata.org/entity/Q12352862', 'http://www.wikidata.org/entity/Q95185946', 'http://www.wikidata.org/entity/Q3893569', 'http://www.wikidata.org/entity/Q92665192', 'http://www.wikidata.org/entity/Q78476861', 'http://www.wikidata.org/entity/Q91335909', 'http://www.wikidata.org/entity/Q91337300', 'http://www.wikidata.org/entity/Q91337941']
# What is the general manager of Bernard Hinault?: Success, Answer: ['No answer']
# Name the FSK 12 rated 3D film with the highest cost ?: Success, Answer: ['http://www.wikidata.org/entity/Q183555', 'http://www.wikidata.org/entity/Q328695', 'http://www.wikidata.org/entity/Q14772351', 'http://www.wikidata.org/entity/Q161687', 'http://www.wikidata.org/entity/Q18407657']
# How many are interested in Daniel Dennett?: Success, Answer: ['4']
# In 1996, what significant event happened in the administrative territorial entity of Bristol?: Success, Answer: ['No answer']
# Where is the river source of the Rhine?: Success, Answer: ['No answer']
# What was Cate Blanchett nominated for her work in I'm Not There?: Success, Answer: ['No answer']
# Tell me the tower that is depicted as Tower of Babel and contains the word babel in it's name?: Success, Answer: ['No answer']
# What position was held by Harold Macmillan in the 34th Parliament of the United Kingdom, when was he elected, and why did he leave?: Success, Answer: ['No answer']
# is the maximum wavelength of sensitivity of the human eye equal to 700?: Success, Answer: ['True']
# Where was the location of birth of Hermann Heinrich Gossen, that has Q48460 such that 2--4355126?: Success, Answer: ['No answer']
# Who received the Nobel Prize in Literature after Mo Yan?: Success, Answer: ['No answer']
# When did Eiji Toyoda win an award for his work in Order of Prince Henry?: Success, Answer: ['No answer']
# When was Jimmy Wales employed as Bomis and when did he leave?: Success, Answer: ['No answer']
# Which is the author of afterword of Erich Fromm?: Success, Answer: ['http://www.wikidata.org/entity/Q24704731']
# Who are worked for Michelle Wolf and its source location of group/organisation is located in New York City?: Success, Answer: ['http://www.wikidata.org/entity/Q813018']
# What are the unit of measurement which start with the letter visus: Success, Answer: ['http://www.wikidata.org/entity/Q19915205', 'visus']
# what was the publication date for iTunes which has software version as 12.7.5?: Success, Answer: ['No answer']
# Dennis M. Ritchie designed which structured programming language?: Success, Answer: ['http://www.wikidata.org/entity/Q15777']
# What role does Mickey Mouse play in the creative work of Ben Sharpsteen?: Success, Answer: ['No answer']
# What is the stock exchange for the ticker symbol 0700 in Tencent?: Success, Answer: ['No answer']
# What are the head of state and the office held by head of state of the Soviet Union?: Success, Answer: ['http://www.wikidata.org/entity/Q30487', 'http://www.wikidata.org/entity/Q1255261']
# What is the name of award recieved for Dawn Fraser has participant of 1960 Summer Olympics ?: Success, Answer: ['No answer']
# What is the parent organization for the International Court of Justice?: Success, Answer: ['http://www.wikidata.org/entity/Q1065']
# What is the beginning of Sarajevo's: Success, Answer: ['No answer']
# What significant event in 1978-6-1 is Michelle Bachelet known for?: Success, Answer: ['No answer']
# What is the solubility of methyl chloride in water?: Success, Answer: ['No answer']
# What five U.S. states does the Delaware River drain from?: Success, Answer: ['No answer']
# None: Success, Answer: ['No answer']
# Which birth language is Chizoba Ejike?: Success, Answer: ['No answer']
# What is the ionization energy of the nicotine?: Success, Answer: ['No answer']
# Is tuberculosis prevalent?: Success, Answer: ['0.0001', '0.00044', '0.00078', '0.000028', '0.000029', '0.0000012', '0.0000043']
# Who is {creators} of {language of the original work} {Star Trek Into Darkness} ?: Success, Answer: ['http://www.wikidata.org/entity/Q714935']
# Who is the spouse of Aaliyah and when did they divorce?: Success, Answer: ['No answer']
# What is {inhabitants} {nationality} of {Leopold von Sacher-Masoch} ?: Success, Answer: ['8809212']
# What is the affiliation building in Columbia University: Success, Answer: ['http://www.wikidata.org/entity/Q1196251']
# What is the commune of France with the lowest population whose located in time zone is UTC+01:00?: Failure, Answer: ['No answer']
# What is the district of the city with the MAX(number of houses whose instance of is district of the city?: Success, Answer: ['http://www.wikidata.org/entity/Q77663083', 'http://www.wikidata.org/entity/Q77663356', 'http://www.wikidata.org/entity/Q3566096', 'http://www.wikidata.org/entity/Q683092', 'http://www.wikidata.org/entity/Q2448746']
# What is Bram Stoker's occupation and field of work and did he work in Dublin Castle?: Success, Answer: ['No answer']
# How many seasons of Handball-Bundesliga are there?: Success, Answer: ['No answer']
# "What is place of residence of Wangari Maathai,that has inflation rate of consumer price index as 2.9?": Success, Answer: ['No answer']
# Who is the child of Pompey and the mother, Mucia Tertia?: Success, Answer: ['No answer']
# Name an alcoholic beverage that contains the word "rum " in its name: Success, Answer: ['No answer']
# How many terminus are in Vienna: Success, Answer: ['6']
# What is in the region of Paroo River, that divides into Ku-ring-gai Council?: Success, Answer: ['http://www.wikidata.org/entity/Q3224']
# What has been the ister city of Changchun since Aug 25th, 1992?: Success, Answer: ['No answer']
# How many rivers and lakes are connected to Lake Urmia?: Success, Answer: ['3']
# Tell me soil type whose name has the word vertisol in it.: Success, Answer: ['http://www.wikidata.org/entity/Q1192084', 'Vertisol']
# What is Lizzy Yarnold's TheSports.org athlete ID?: Success, Answer: ['83904']
# What is { award received } from { Justin Timberlake } that is { point in time } is { 2007 - 0 - 0 }?: Success, Answer: ['No answer']
# Which religious concept starts with the letter t: Success, Answer: ['http://www.wikidata.org/entity/Q181510', 'Tantra', 'http://www.wikidata.org/entity/Q1123552', 'Tapas', 'http://www.wikidata.org/entity/Q214500', 'transubstantiation', 'http://www.wikidata.org/entity/Q3539698', 'Trishula', 'http://www.wikidata.org/entity/Q1772811', 'Treta Yuga', 'http://www.wikidata.org/entity/Q1330245', 'Tat Tvam Asi', 'http://www.wikidata.org/entity/Q1509831', 'title of Virgin Mary', 'http://www.wikidata.org/entity/Q4451306', 'Tantra in Buddhism', 'http://www.wikidata.org/entity/Q3232061', 'Two truths doctrine', 'http://www.wikidata.org/entity/Q693230', 'Tathatā/Dharmatā', 'http://www.wikidata.org/entity/Q16518197', 'Tantra in Hinduism', 'http://www.wikidata.org/entity/Q1069584', 'Trikaya', 'http://www.wikidata.org/entity/Q1135471', 'Tathāgatagarbha', 'http://www.wikidata.org/entity/Q1474574', 'Taṇhā', 'http://www.wikidata.org/entity/Q2634521', 'title of Jesus', 'http://www.wikidata.org/entity/Q1045328', 'Tianlong babu', 'http://www.wikidata.org/entity/Q4178700', 'theologoumenon', 'http://www.wikidata.org/entity/Q1061285', 'Tathāgata', 'http://www.wikidata.org/entity/Q3235905', 'Three Turnings of the Wheel of Dharma', 'http://www.wikidata.org/entity/Q10904910', 'Thousand-armed Avalokiteśvara', 'http://www.wikidata.org/entity/Q10942956', 'Thus have I heard', 'http://www.wikidata.org/entity/Q1129863', 'Theosis', 'http://www.wikidata.org/entity/Q3538361', 'Thirteen Buddhas', 'http://www.wikidata.org/entity/Q3451071', 'triple deity', 'http://www.wikidata.org/entity/Q1156452', 'Trailokya']
# Is it true that the explosive energy equivalent of Father of All Bombs is less than 52.8?: Success, Answer: ['True']
# When did child of Abigail Adams and date of birth?: Success, Answer: ['No answer']
# Does the Becherovka alcohol by volume less than 30.4: Success, Answer: ['False']
# What are the prefecture-level city  which start with the letter ürümqi: Success, Answer: ['http://www.wikidata.org/entity/Q16959', 'Ürümqi']
# tell me ceremony whose name has the word umhlanga in it: Success, Answer: ['http://www.wikidata.org/entity/Q2382828', 'Umhlanga']
# Which is {played as} of {symbol} of {inequality} ?: Success, Answer: ['http://www.wikidata.org/entity/Q165309']
# What is edition runtime for League of Legends?: Success, Answer: ['http://www.wikidata.org/entity/Q11248', 'http://www.wikidata.org/entity/Q18168774', 'http://www.wikidata.org/entity/Q495432', 'http://www.wikidata.org/entity/Q83370', 'http://www.wikidata.org/entity/Q21207', 'http://www.wikidata.org/entity/Q11215', 'http://www.wikidata.org/entity/Q11230', 'http://www.wikidata.org/entity/Q5046', 'http://www.wikidata.org/entity/Q29758', 'http://www.wikidata.org/entity/Q4163181', 'http://www.wikidata.org/entity/Q6072277', 'http://www.wikidata.org/entity/Q4885200', 'http://www.wikidata.org/entity/Q483132', 'http://www.wikidata.org/entity/Q3569290', 'http://www.wikidata.org/entity/Q8024430', 'http://www.wikidata.org/entity/Q1064344', 'http://www.wikidata.org/entity/Q4020349', 'http://www.wikidata.org/entity/Q483881', 'http://www.wikidata.org/entity/Q484892', 'http://www.wikidata.org/entity/Q485021', 'http://www.wikidata.org/entity/Q488978', 'http://www.wikidata.org/entity/Q58378', 'http://www.wikidata.org/entity/Q771202', 'http://www.wikidata.org/entity/Q737508', 'http://www.wikidata.org/entity/Q2643528', 'http://www.wikidata.org/entity/Q107269746', 'http://www.wikidata.org/entity/Q11246', 'http://www.wikidata.org/entity/Q15282750', 'http://www.wikidata.org/entity/Q34825', 'http://www.wikidata.org/entity/Q1087636', 'http://www.wikidata.org/entity/Q1152115', 'http://www.wikidata.org/entity/Q488244', 'http://www.wikidata.org/entity/Q11222', 'http://www.wikidata.org/entity/Q11226', 'http://www.wikidata.org/entity/Q11233', 'http://www.wikidata.org/entity/Q19754851', 'http://www.wikidata.org/entity/Q3340004', 'http://www.wikidata.org/entity/Q1347061', 'http://www.wikidata.org/entity/Q858368', 'http://www.wikidata.org/entity/Q8024433', 'http://www.wikidata.org/entity/Q15222398', 'http://www.wikidata.org/entity/Q15926623', 'http://www.wikidata.org/entity/Q1854343', 'http://www.wik
# Tell me the most notable work of Christopher Hitchens and also the publisher.: Success, Answer: ['No answer']
# What is the INSEE countries and foreign territories code for the Democratic Republic of Congo?: Success, Answer: ['99312']

# %% [markdown]
# ## Results wikidata query test with first 200 queries
# Most of the queries can be exceuted and return correct results. However there are also so which don't return any answers. After checking those queries manually, for most of them the information is not available anymore, has been updated, changed or the connected entities are not available anymore.
#
# **template_id: "statement_property_2**: After manually checking the query results, it appears that all queries with the template_id "statement_property_1" & "statement_property_2" are not working. This is due to the fact that the endpoint is not able to execute the queries. The queries are not working in the skynet web interface, however most of them are working in wiki data query service (https://query.wikidata.org/). Those templates are also the ones which include qualifiers, which might be the reason for the failure.
#
# For example:
# When position did Angela Merkel hold on November 10, 1994? (template_id: "statement_property_2"). When executing it in skynet with the following query:
# ```
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
# PREFIX wd: <http://www.wikidata.org/entity/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX p: <http://www.wikidata.org/prop/>
# PREFIX ps: <http://www.wikidata.org/prop/statement/>
# PREFIX pq: <http://www.wikidata.org/prop/qualifier/>
#
# SELECT ?obj WHERE { wd:Q567 p:P39 ?s . ?s ps:P39 ?obj . ?s pq:P580 ?x filter(contains(YEAR(?x),'1994'))}
# ```
#
# It says: "No data available in table"
#
# When executing it in wiki data query service:
#
# ```
# SELECT ?obj WHERE { wd:Q567 p:P39 ?s . ?s ps:P39 ?obj . ?s pq:P580 ?x filter(contains(YEAR(?x),'1994'))}
# ```
# It returns the correct answer:
# wd:Q30544097 & wd:Q1939555

# %% [markdown]
# ## Test for DBpedia endpoint

# %%
# Define the DBpedia SPARQL endpoint
DBPEDIA_ENDPOINT = "http://localhost:8897/sparql"

# Add prefixes for DBpedia queries
DBPEDIA_PREFIXES = """
PREFIX as: <http://www.w3.org/ns/activitystreams#>
PREFIX bif: <bif:>
PREFIX dawgt: <http://www.w3.org/2001/sw/DataAccess/tests/test-dawg#>
PREFIX dbpedia: <http://dbpedia.org/resource/>
PREFIX dbpprop: <http://dbpedia.org/property/>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX fn: <http://www.w3.org/2005/xpath-functions/#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX go: <http://purl.org/obo/owl/GO#>
PREFIX ldp: <http://www.w3.org/ns/ldp#>
PREFIX math: <http://www.w3.org/2000/10/swap/math#>
PREFIX mesh: <http://purl.org/commons/record/mesh/>
PREFIX mf: <http://www.w3.org/2001/sw/DataAccess/tests/test-manifest#>
PREFIX nci: <http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#>
PREFIX obo: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX ogc: <http://www.opengis.net/>
PREFIX ogcgml: <http://www.opengis.net/ont/gml#>
PREFIX ogcgs: <http://www.opengis.net/ont/geosparql#>
PREFIX ogcgsf: <http://www.opengis.net/def/function/geosparql/>
PREFIX ogcgsr: <http://www.opengis.net/def/rule/geosparql/>
PREFIX ogcsf: <http://www.opengis.net/ont/sf#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX product: <http://www.buy.com/rss/module/productV2/>
PREFIX protseq: <http://purl.org/science/protein/bysequence/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfa: <http://www.w3.org/ns/rdfa#>
PREFIX rdfdf: <http://www.openlinksw.com/virtrdf-data-formats#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX sc: <http://purl.org/science/owl/sciencecommons/>
PREFIX scovo: <http://purl.org/NET/scovo#>
PREFIX sd: <http://www.w3.org/ns/sparql-service-description#>
PREFIX sioc: <http://rdfs.org/sioc/ns#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX sql: <sql:>
PREFIX vcard: <http://www.w3.org/2001/vcard-rdf/3.0#>
PREFIX vcard2006: <http://www.w3.org/2006/vcard/ns#>
PREFIX virtcxml: <http://www.openlinksw.com/schemas/virtcxml#>
PREFIX virtrdf: <http://www.openlinksw.com/schemas/virtrdf#>
PREFIX void: <http://rdfs.org/ns/void#>
PREFIX xf: <http://www.w3.org/2004/07/xpath-functions>
PREFIX xml: <http://www.w3.org/XML/1998/namespace>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX xsl10: <http://www.w3.org/XSL/Transform/1.0>
PREFIX xsl1999: <http://www.w3.org/1999/XSL/Transform>
PREFIX xslwd: <http://www.w3.org/TR/WD-xsl>
PREFIX yago: <http://dbpedia.org/class/yago/>
"""

def add_dbpedia_prefixes(sparql_query):
    """Add required prefixes to the SPARQL query for DBpedia."""
    return DBPEDIA_PREFIXES + sparql_query

# Query the SPARQL endpoint using the SPARQLWrapper library
def query_sparql(endpoint, query):
    """Send a SPARQL query to the specified endpoint and return the results."""
    sparql = SPARQLWrapper(endpoint)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    sparql.setMethod('GET')
    sparql.setTimeout(60)  # Set timeout to 60 seconds to avoid long waits
    try:
        return sparql.query().convert()  # Return results for further processing
    except Exception as e:
        print(f"Query failed: {e}")
        return None  # Query failed

# Extract answers from DBpedia SPARQL results
def extract_answer(results):
    """Extract the answer from the SPARQL query results, handling boolean answers."""
    if not results:
        return ["No answer"]
    
    if 'boolean' in results:
        return ["True"] if results['boolean'] else ["False"]

    answers = []
    bindings = results.get('results', {}).get('bindings', [])
    if not bindings:
        return ["No answer"]

    for binding in bindings:
        for var_name in binding:
            value = binding[var_name]['value']
            if value.startswith("http://dbpedia.org/resource/"):
                answers.append(value)  # Keep the full DBpedia link
            else:
                answers.append(value)  # Append literals directly
    return answers if answers else ["No answer"]

# Initialize counters for proper/correct answers, no answers, and failures
proper_answer_count = 0
no_answer_count = 0
failure_count = 0

# Lists to hold query results
results = []

# Test the first 1000 queries for DBpedia
for entry in lc_quad_data[:1000]:
    sparql_query = entry.get('sparql_dbpedia18')  # Use DBpedia-specific queries
    question = entry.get('question')
    
    if sparql_query:
        # Add the necessary prefixes to the query
        query_with_prefixes = add_dbpedia_prefixes(sparql_query)
        result = query_sparql(DBPEDIA_ENDPOINT, query_with_prefixes)
        
        if result:
            answer = extract_answer(result)
            if "No answer" in answer:
                no_answer_count += 1
            else:
                proper_answer_count += 1
            results.append((question, 'Success', answer))
        else:
            failure_count += 1
            results.append((question, 'Failure', ['No answer']))

# Print the number of proper answers, no answers, and failures
print(f"Number of queries with proper answers: {proper_answer_count}")
print(f"Number of queries with no answers: {no_answer_count}")
print(f"Number of failed queries: {failure_count}")

# Prepare data for exporting to Excel
df = pd.DataFrame(results, columns=['Question', 'Result', 'Answer'])

# Save results to an Excel file for further inspection
df.to_excel("dbpedia_results.xlsx", index=False)

# Visualize the results with a bar chart
labels = ['Proper Answer', 'No Answer', 'Failures']
sizes = [proper_answer_count, no_answer_count, failure_count]

plt.bar(labels, sizes, color=['blue', 'orange', 'red'])
for i in range(len(labels)):
    plt.text(i, sizes[i] + 0.5, str(sizes[i]), ha='center')

plt.title('Count of Queries: Proper Answers vs No Answers vs Failures (DBpedia)')
plt.ylabel('Number of Queries')
plt.xlabel('Answer Type')
plt.show()

# Optionally print the results for inspection
for question, result, answer in results:
    print(f"{question}: {result}, Answer: {answer}")
# Out:
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 112
#     109 if sparql_query:
#     110     # Add the necessary prefixes to the query
#     111     query_with_prefixes = add_dbpedia_prefixes(sparql_query)
# --> 112     result = query_sparql(DBPEDIA_ENDPOINT, query_with_prefixes)
#     114     if result:
#     115         answer = extract_answer(result)
#
# Cell In[4], line 68, in query_sparql(endpoint, query)
#      66 sparql.setTimeout(60)  # Set timeout to 60 seconds to avoid long waits
#      67 try:
# ---> 68     return sparql.query().convert()  # Return results for further processing
#      69 except Exception as e:
#      70     print(f"Query failed: {e}")
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\site-packages\SPARQLWrapper\Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)
#     958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\site-packages\SPARQLWrapper\Wrapper.py:924, in SPARQLWrapper._query(self)
#     922 try:
#     923     if self.timeout:
# --> 924         response = urlopener(request, timeout=self.timeout)
#     925     else:
#     926         response = urlopener(request)
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:189, in urlopen(url, data, timeout, context)
#     187 else:
#     188     opener = _opener
# --> 189 return opener.open(url, data, timeout)
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:489, in OpenerDirector.open(self, fullurl, data, timeout)
#     486     req = meth(req)
#     488 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 489 response = self._open(req, data)
#     491 # post-process response
#     492 meth_name = protocol+"_response"
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:506, in OpenerDirector._open(self, req, data)
#     503     return result
#     505 protocol = req.type
# --> 506 result = self._call_chain(self.handle_open, protocol, protocol +
#     507                           '_open', req)
#     508 if result:
#     509     return result
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     464 for handler in handlers:
#     465     func = getattr(handler, meth_name)
# --> 466     result = func(*args)
#     467     if result is not None:
#     468         return result
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:1348, in HTTPHandler.http_open(self, req)
#    1347 def http_open(self, req):
# -> 1348     return self.do_open(http.client.HTTPConnection, req)
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:1323, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1321     except OSError as err: # timeout error
#    1322         raise URLError(err)
# -> 1323     r = h.getresponse()
#    1324 except:
#    1325     h.close()
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\malte\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def adjust_dbpedia_query(sparql_query):
    """
    Adjusts a query written for 'sparql_dbpedia18' by replacing Wikidata URIs with DBpedia URIs.
    """
    sparql_query = sparql_query.replace("http://wikidata.dbpedia.org/resource/", "http://dbpedia.org/resource/")
    sparql_query = sparql_query.replace("http://www.wikidata.org/entity/", "http://dbpedia.org/ontology/")
    sparql_query = sparql_query.replace("rdf:type", "dbo:type")
    # Add more property-specific replacements as needed
    return sparql_query

# %%
for entry in lc_quad_data[:100]:
    sparql_query = entry.get('sparql_dbpedia18')  # Use DBpedia-specific queries
    question = entry.get('question')

    if sparql_query:
        # Adjust the query to resolve DBpedia resources and properties
        query_with_prefixes = add_dbpedia_prefixes(adjust_dbpedia_query(sparql_query))
        result = query_sparql(DBPEDIA_ENDPOINT, query_with_prefixes)
        
        if result:
            answer = extract_answer(result)
            if "No answer" in answer:
                no_answer_count += 1
            else:
                proper_answer_count += 1
            results.append((question, 'Success', answer))
        else:
            failure_count += 1
            results.append((question, 'Failure', ['No answer']))
            
# Print the number of proper answers, no answers, and failures
print(f"Number of queries with proper answers: {proper_answer_count}")
print(f"Number of queries with no answers: {no_answer_count}")
print(f"Number of failed queries: {failure_count}")

# Prepare data for exporting to Excel
df = pd.DataFrame(results, columns=['Question', 'Result', 'Answer'])

# Save results to an Excel file for further inspection
df.to_excel("dbpedia_results.xlsx", index=False)

# Visualize the results with a bar chart
labels = ['Proper Answer', 'No Answer', 'Failures']
sizes = [proper_answer_count, no_answer_count, failure_count]

plt.bar(labels, sizes, color=['blue', 'orange', 'red'])
for i in range(len(labels)):
    plt.text(i, sizes[i] + 0.5, str(sizes[i]), ha='center')

plt.title('Count of Queries: Proper Answers vs No Answers vs Failures (DBpedia)')
plt.ylabel('Number of Queries')
plt.xlabel('Answer Type')
plt.show()

# Optionally print the results for inspection
for question, result, answer in results:
    print(f"{question}: {result}, Answer: {answer}")
# Out:
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Query failed: Remote end closed connection without response
# Number of queries with proper answers: 0
# Number of queries with no answers: 0
# Number of failed queries: 218
# What periodical literature does Delta Air Lines use as a moutpiece?: Failure, Answer: ['No answer']
# Who is the child of Ranavalona I's husband?: Failure, Answer: ['No answer']
# Is it true Jeff_Bridges occupation Lane Chandler and photographer ?: Failure, Answer: ['No answer']
# What is the pre-requisite of phase matter of Galinstan?: Failure, Answer: ['No answer']
# Which is the operating income for Qantas?: Failure, Answer: ['No answer']
# which cola starts with the letter p: Failure, Answer: ['No answer']
# Is the right ascension of malin 1 less than 15.1398?: Failure, Answer: ['No answer']
# What is the complete list of records released by Jerry Lee Lewis?: Failure, Answer: ['No answer']
# What's Mary Lou Retton's International Olympic Committee athlete ID.: Failure, Answer: ['No answer']
# Who won the prize at the sequel of the 1885 Wimbledon Championships- Gentlemen's Singles?: Failure, Answer: ['No answer']
# Is it true that the carbon footprint of the iPhone X Max is 106?: Failure, Answer: ['No answer']
# Tell me the female beauty pageant that operates in all countries and contains the word model in it's name?: Failure, Answer: ['No answer']
# Did Lindsey Vonn participate in the FIS Alpine World Ski Championships in 1999 and 2019?: Failure, Answer: ['No answer']
# When position did Angela Merkel hold on November 10, 1994?: Failure, Answer: ['No answer']
# On 0-0-2007, what is the populaton of Spokane?: Failure, Answer: ['No answer']
# What essential medicine is needed to treat leprosy?: Failure, Answer: ['No answer']
# Which is HanCinema person ID for Zhang Ziyi?: Failure, Answer: ['No answer']
# Did Judi Densch receive a Tony Award for best direction of the play Premium Imperiale?: Failure, Answer: ['No answer']
# What is the boiling point of pressure copper as 4703.0?: Failure, Answer: ['No answer']
# After what is Marathon named and what is the current record?: Failure, Answer: ['No answer']
# Who Sleepwalking succeeded in playing Sleepwalking?: Failure, Answer: ['No answer']
# What did Clifton Chenier get nominated for in 1983-0-0?: Failure, Answer: ['No answer']
# Which is the wear for Ambrose Burnside?: Failure, Answer: ['No answer']
# Which Class IB flammable liquid has the least lower flammable limit?: Failure, Answer: ['No answer']
# What is the material used and approved by Mojito?: Failure, Answer: ['No answer']
# Could you summarize Korea's history of this topic?: Failure, Answer: ['No answer']
# "Which is {landscape of} of {Virgin of the rocks}, which has {birth city} is {Tzippori} ?": Failure, Answer: ['No answer']
# Is Kevin Costner owner of Fielders Stadium?: Failure, Answer: ['No answer']
# Which is the YouTube channel ID for Miley Cyrus?: Failure, Answer: ['No answer']
# What is a skill that starts with the letter s.: Failure, Answer: ['No answer']
# How many dimensions have a Captain America?: Failure, Answer: ['No answer']
# What award did Danila Kozlovsky receive in 2017?: Failure, Answer: ['No answer']
# Who is the student that coined the Euler-Lagrange equation?: Failure, Answer: ['No answer']
# Which website does Twitch own?: Failure, Answer: ['No answer']
# Is the minimal lethal dose of the benzene equal to 170000?: Failure, Answer: ['No answer']
# Who is the person that was a student of Ivan Pavlov?: Failure, Answer: ['No answer']
# is the clock speed of the Watara Supervision smaller than 3.2?: Failure, Answer: ['No answer']
# What country is the current leader of the African Union ?: Failure, Answer: ['No answer']
# Who works for the accused Mariposa Folk Festival 1974?: Failure, Answer: ['No answer']
# n/a: Failure, Answer: ['No answer']
# What sister city was born in of Zakhar Oskotsky?: Failure, Answer: ['No answer']
# Tell me the name of a fantastique genre that starts with the letter s.: Failure, Answer: ['No answer']
# What is the medal Angela Lansbury recieved?: Failure, Answer: ['No answer']
# What is the musical score by Missa Solemnis that has mother Maria Magdalena van Beethoven?: Failure, Answer: ['No answer']
# When did Robert De Niro reside in Marbletown?: Failure, Answer: ['No answer']
# Tell me organization whose name has the word  zollkriminalamt  in it.: Failure, Answer: ['No answer']
# Which member state of the International Centre for Settlement of Investment Disputes has the maximum inflation rate?: Failure, Answer: ['No answer']
# Was Brittany Murphy a citizen of the USA?: Failure, Answer: ['No answer']
# Who is the partner and the spouse of Hank Azaria?: Failure, Answer: ['No answer']
# Does St. Peters Junior School maximum age equal to 11?: Failure, Answer: ['No answer']
# Which country has highest individual tax rate?: Failure, Answer: ['No answer']
# When did James Thomas Farrell receive the St. Louis Literary Award?: Failure, Answer: ['No answer']
# When was Pablo Picasso's partnership with Fernade Oliver over?: Failure, Answer: ['No answer']
# What is the product with the lowest consumption rate per capita whose has part is paraffin wax?: Failure, Answer: ['No answer']
# What are the coordinates for the geographic center of Michigan, as determined by the center of gravity of the surface?: Failure, Answer: ['No answer']
# Is the life expectancy of Indonesia 55.3528?: Failure, Answer: ['No answer']
# When did Emmerson Mnangagwa begin going to the University of Zambia?: Failure, Answer: ['No answer']
# What kind of career does Grigori Kozintsev have in the screenwriting field?: Failure, Answer: ['No answer']
# what is hypothetical protein ecia139-4120 habitat of found in species?: Failure, Answer: ['No answer']
# What sovereign state replaced the Kingdom of Great Britain?: Failure, Answer: ['No answer']
# Of the century breaks of the Colm Gilcreest equal less than 9.6?: Failure, Answer: ['No answer']
# In which country the Golden Horde used to live ?: Failure, Answer: ['No answer']
# Located in the Central District, what is the county seat whose twin cities include Feodosiya?: Failure, Answer: ['No answer']
# When did Nicaragua count a population of 3.87732e+06 inhabitants?: Failure, Answer: ['No answer']
# What does emigration mean?: Failure, Answer: ['No answer']
# Which is the meta-organization that is regulated by the football association?: Failure, Answer: ['No answer']
# When was the spouse divorced Nero in 9-6-68: Failure, Answer: ['No answer']
# n/a: Failure, Answer: ['No answer']
# Former champion Francisco Alarcon gave what award to Art Spiegelaman?: Failure, Answer: ['No answer']
# Are there more than 0 survivors of the Charkhi Dadri mid-air collision: Failure, Answer: ['No answer']
# When did Secretariat receive the Triple Crown Trophy?: Failure, Answer: ['No answer']
# Which borders of borders of Riverside have a start date of 1984-0-0?: Failure, Answer: ['No answer']
# Which is the facility of the defensive wall?: Failure, Answer: ['No answer']
# What is  in the IHO Hydrographic Dictionary (S-32) Number of lighthouse ?: Failure, Answer: ['No answer']
# Which is the fictional analog of Hippocampus?: Failure, Answer: ['No answer']
# What is a cause of death that begins with the letter "p" and can be found on a CT scan?: Failure, Answer: ['No answer']
# What is established by Archbishop of Canterbury, who is a male?: Failure, Answer: ['No answer']
# In what area is Fernandel buried at the Passy Cemetery?: Failure, Answer: ['No answer']
# Name the naval artillery wirh the smallest firing range?: Failure, Answer: ['No answer']
# What is the name of a Cayenne Pepper that also has dates?: Failure, Answer: ['No answer']
# Is the throughput of the Vest-vassdraget equal to 2697.672?: Failure, Answer: ['No answer']
# What method did the census use to determine the population of Taguig?: Failure, Answer: ['No answer']
# What award did Olga Tokarczuk receive in 2015?: Failure, Answer: ['No answer']
# What is Porky Pig in right now?: Failure, Answer: ['No answer']
# When did publisher of Pac-Man and place of publication?: Failure, Answer: ['No answer']
# Was Aleister Crowley educated at Trinity College and Eton College?: Failure, Answer: ['No answer']
# What is {located next to Quincy,} in the {novel, Infinite Jest}?: Failure, Answer: ['No answer']
# Who awarded Eric Hobsbawm an honorary doctorate?: Failure, Answer: ['No answer']
# What was the last team Allan Border belonged to in the year 1980?: Failure, Answer: ['No answer']
# Give me a film character from a fictional universe, such as Marvel comics that starts with a W.: Failure, Answer: ['No answer']
# Mention the fictional universe described or included in The Matrix.: Failure, Answer: ['No answer']
# What is {award received} of {Hans Krebs} where {point in time} is {1966-0-0} ?: Failure, Answer: ['No answer']
# Which record label signed Janet Jackson?: Failure, Answer: ['No answer']
# What is Tanzania's total reserves?: Failure, Answer: ['No answer']
# Does the slope rating of the Merion Golf Club equal 149: Failure, Answer: ['No answer']
# What is the density of hydrogen peroxide at a temperature of 20.0?: Failure, Answer: ['No answer']
# who architecture firm of home field of new york centaurs?: Failure, Answer: ['No answer']
# Which { meansseason starts} in {February} ?: Failure, Answer: ['No answer']
# Who is {champ} of {prize awarded} {Lily Tomlin} ?: Failure, Answer: ['No answer']
# What is the ammunition of the weapon, that has been used in the war in Southeast Asia?: Failure, Answer: ['No answer']
# Tell me every horse breed whose name starts with the letter z: Failure, Answer: ['No answer']
# The University of Florida is a member of which coalition?: Failure, Answer: ['No answer']
# Who is the brother in law of the writer Quran?: Failure, Answer: ['No answer']
# What is the New Zealand Gazetteer place id for Auckland?: Failure, Answer: ['No answer']
# What does the painting Grade Odalisque represent which has DRTL backwards?: Failure, Answer: ['No answer']
# Name an empire that contains the word "british" in its name: Failure, Answer: ['No answer']
# What is the instance of Antonio da Correggio whose date of birth is 1489-8-1?: Failure, Answer: ['No answer']
# Who was the teacher that supervised Shigeno Yasutsugu?: Failure, Answer: ['No answer']
# What is the SANDRE ID for Rhine?: Failure, Answer: ['No answer']
# When did Kylie Minogue receive the Gold Logie Award for Most Popular Personality on Australian Television?: Failure, Answer: ['No answer']
# What business does Alexander McQueen have?: Failure, Answer: ['No answer']
# Tell me the Greek deity of sibling of Zeus and that contains the word poseidon in it's name?: Failure, Answer: ['No answer']
# Who organizes the order of Ultima III: Exodus?: Failure, Answer: ['No answer']
# Who was the lead actor for the movie Deadpool?: Failure, Answer: ['No answer']
# Mention the musical related work highlighting the work of Sasha Grey.: Failure, Answer: ['No answer']
# What award did John de Mol receive in 2011?: Failure, Answer: ['No answer']
# Is the total fertility rate of Algeria greater than 3.4284?: Failure, Answer: ['No answer']
# When will the pressure and temperature of water reach the triple point stage?: Failure, Answer: ['No answer']
# What periodical literature does Delta Air Lines use as a moutpiece?: Failure, Answer: ['No answer']
# Who is the child of Ranavalona I's husband?: Failure, Answer: ['No answer']
# Is it true Jeff_Bridges occupation Lane Chandler and photographer ?: Failure, Answer: ['No answer']
# What is the pre-requisite of phase matter of Galinstan?: Failure, Answer: ['No answer']
# Which is the operating income for Qantas?: Failure, Answer: ['No answer']
# which cola starts with the letter p: Failure, Answer: ['No answer']
# Is the right ascension of malin 1 less than 15.1398?: Failure, Answer: ['No answer']
# What is the complete list of records released by Jerry Lee Lewis?: Failure, Answer: ['No answer']
# What's Mary Lou Retton's International Olympic Committee athlete ID.: Failure, Answer: ['No answer']
# Who won the prize at the sequel of the 1885 Wimbledon Championships- Gentlemen's Singles?: Failure, Answer: ['No answer']
# Is it true that the carbon footprint of the iPhone X Max is 106?: Failure, Answer: ['No answer']
# Tell me the female beauty pageant that operates in all countries and contains the word model in it's name?: Failure, Answer: ['No answer']
# Did Lindsey Vonn participate in the FIS Alpine World Ski Championships in 1999 and 2019?: Failure, Answer: ['No answer']
# When position did Angela Merkel hold on November 10, 1994?: Failure, Answer: ['No answer']
# On 0-0-2007, what is the populaton of Spokane?: Failure, Answer: ['No answer']
# What essential medicine is needed to treat leprosy?: Failure, Answer: ['No answer']
# Which is HanCinema person ID for Zhang Ziyi?: Failure, Answer: ['No answer']
# Did Judi Densch receive a Tony Award for best direction of the play Premium Imperiale?: Failure, Answer: ['No answer']
# What is the boiling point of pressure copper as 4703.0?: Failure, Answer: ['No answer']
# After what is Marathon named and what is the current record?: Failure, Answer: ['No answer']
# Who Sleepwalking succeeded in playing Sleepwalking?: Failure, Answer: ['No answer']
# What did Clifton Chenier get nominated for in 1983-0-0?: Failure, Answer: ['No answer']
# Which is the wear for Ambrose Burnside?: Failure, Answer: ['No answer']
# Which Class IB flammable liquid has the least lower flammable limit?: Failure, Answer: ['No answer']
# What is the material used and approved by Mojito?: Failure, Answer: ['No answer']
# Could you summarize Korea's history of this topic?: Failure, Answer: ['No answer']
# "Which is {landscape of} of {Virgin of the rocks}, which has {birth city} is {Tzippori} ?": Failure, Answer: ['No answer']
# Is Kevin Costner owner of Fielders Stadium?: Failure, Answer: ['No answer']
# Which is the YouTube channel ID for Miley Cyrus?: Failure, Answer: ['No answer']
# What is a skill that starts with the letter s.: Failure, Answer: ['No answer']
# How many dimensions have a Captain America?: Failure, Answer: ['No answer']
# What award did Danila Kozlovsky receive in 2017?: Failure, Answer: ['No answer']
# Who is the student that coined the Euler-Lagrange equation?: Failure, Answer: ['No answer']
# Which website does Twitch own?: Failure, Answer: ['No answer']
# Is the minimal lethal dose of the benzene equal to 170000?: Failure, Answer: ['No answer']
# Who is the person that was a student of Ivan Pavlov?: Failure, Answer: ['No answer']
# is the clock speed of the Watara Supervision smaller than 3.2?: Failure, Answer: ['No answer']
# What country is the current leader of the African Union ?: Failure, Answer: ['No answer']
# Who works for the accused Mariposa Folk Festival 1974?: Failure, Answer: ['No answer']
# n/a: Failure, Answer: ['No answer']
# What sister city was born in of Zakhar Oskotsky?: Failure, Answer: ['No answer']
# Tell me the name of a fantastique genre that starts with the letter s.: Failure, Answer: ['No answer']
# What is the medal Angela Lansbury recieved?: Failure, Answer: ['No answer']
# What is the musical score by Missa Solemnis that has mother Maria Magdalena van Beethoven?: Failure, Answer: ['No answer']
# When did Robert De Niro reside in Marbletown?: Failure, Answer: ['No answer']
# Tell me organization whose name has the word  zollkriminalamt  in it.: Failure, Answer: ['No answer']
# Which member state of the International Centre for Settlement of Investment Disputes has the maximum inflation rate?: Failure, Answer: ['No answer']
# Was Brittany Murphy a citizen of the USA?: Failure, Answer: ['No answer']
# Who is the partner and the spouse of Hank Azaria?: Failure, Answer: ['No answer']
# Does St. Peters Junior School maximum age equal to 11?: Failure, Answer: ['No answer']
# Which country has highest individual tax rate?: Failure, Answer: ['No answer']
# When did James Thomas Farrell receive the St. Louis Literary Award?: Failure, Answer: ['No answer']
# When was Pablo Picasso's partnership with Fernade Oliver over?: Failure, Answer: ['No answer']
# What is the product with the lowest consumption rate per capita whose has part is paraffin wax?: Failure, Answer: ['No answer']
# What are the coordinates for the geographic center of Michigan, as determined by the center of gravity of the surface?: Failure, Answer: ['No answer']
# Is the life expectancy of Indonesia 55.3528?: Failure, Answer: ['No answer']
# When did Emmerson Mnangagwa begin going to the University of Zambia?: Failure, Answer: ['No answer']
# What kind of career does Grigori Kozintsev have in the screenwriting field?: Failure, Answer: ['No answer']
# what is hypothetical protein ecia139-4120 habitat of found in species?: Failure, Answer: ['No answer']
# What sovereign state replaced the Kingdom of Great Britain?: Failure, Answer: ['No answer']
# Of the century breaks of the Colm Gilcreest equal less than 9.6?: Failure, Answer: ['No answer']
# In which country the Golden Horde used to live ?: Failure, Answer: ['No answer']
# Located in the Central District, what is the county seat whose twin cities include Feodosiya?: Failure, Answer: ['No answer']
# When did Nicaragua count a population of 3.87732e+06 inhabitants?: Failure, Answer: ['No answer']
# What does emigration mean?: Failure, Answer: ['No answer']
# Which is the meta-organization that is regulated by the football association?: Failure, Answer: ['No answer']
# When was the spouse divorced Nero in 9-6-68: Failure, Answer: ['No answer']
# n/a: Failure, Answer: ['No answer']
# Former champion Francisco Alarcon gave what award to Art Spiegelaman?: Failure, Answer: ['No answer']
# Are there more than 0 survivors of the Charkhi Dadri mid-air collision: Failure, Answer: ['No answer']
# When did Secretariat receive the Triple Crown Trophy?: Failure, Answer: ['No answer']
# Which borders of borders of Riverside have a start date of 1984-0-0?: Failure, Answer: ['No answer']
# Which is the facility of the defensive wall?: Failure, Answer: ['No answer']
# What is  in the IHO Hydrographic Dictionary (S-32) Number of lighthouse ?: Failure, Answer: ['No answer']
# Which is the fictional analog of Hippocampus?: Failure, Answer: ['No answer']
# What is a cause of death that begins with the letter "p" and can be found on a CT scan?: Failure, Answer: ['No answer']
# What is established by Archbishop of Canterbury, who is a male?: Failure, Answer: ['No answer']
# In what area is Fernandel buried at the Passy Cemetery?: Failure, Answer: ['No answer']
# Name the naval artillery wirh the smallest firing range?: Failure, Answer: ['No answer']
# What is the name of a Cayenne Pepper that also has dates?: Failure, Answer: ['No answer']
# Is the throughput of the Vest-vassdraget equal to 2697.672?: Failure, Answer: ['No answer']
# What method did the census use to determine the population of Taguig?: Failure, Answer: ['No answer']
# What award did Olga Tokarczuk receive in 2015?: Failure, Answer: ['No answer']
# What is Porky Pig in right now?: Failure, Answer: ['No answer']
# When did publisher of Pac-Man and place of publication?: Failure, Answer: ['No answer']
# Was Aleister Crowley educated at Trinity College and Eton College?: Failure, Answer: ['No answer']
# What is {located next to Quincy,} in the {novel, Infinite Jest}?: Failure, Answer: ['No answer']
# Who awarded Eric Hobsbawm an honorary doctorate?: Failure, Answer: ['No answer']
# What was the last team Allan Border belonged to in the year 1980?: Failure, Answer: ['No answer']
# Give me a film character from a fictional universe, such as Marvel comics that starts with a W.: Failure, Answer: ['No answer']
# Mention the fictional universe described or included in The Matrix.: Failure, Answer: ['No answer']
# What is {award received} of {Hans Krebs} where {point in time} is {1966-0-0} ?: Failure, Answer: ['No answer']
# Which record label signed Janet Jackson?: Failure, Answer: ['No answer']
# What is Tanzania's total reserves?: Failure, Answer: ['No answer']
# Does the slope rating of the Merion Golf Club equal 149: Failure, Answer: ['No answer']
# What is the density of hydrogen peroxide at a temperature of 20.0?: Failure, Answer: ['No answer']
# who architecture firm of home field of new york centaurs?: Failure, Answer: ['No answer']
# Which { meansseason starts} in {February} ?: Failure, Answer: ['No answer']
# Who is {champ} of {prize awarded} {Lily Tomlin} ?: Failure, Answer: ['No answer']
# What is the ammunition of the weapon, that has been used in the war in Southeast Asia?: Failure, Answer: ['No answer']
